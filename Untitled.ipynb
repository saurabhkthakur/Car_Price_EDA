# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cars_price.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        make    model  priceUSD  year     condition  \
# 0           0       honda   accord       565  1993  with mileage
# 1           1        ford   fusion      5550  2008  with mileage
# 2           2      nissan    teana      8300  2008  with mileage
# 3           3  volkswagen      fox      3300  2005  with mileage
# 4           4      nissan  primera      2450  2002   with damage
#
#    mileage(kilometers) fuel_type  volume(cm3)     color transmission  \
# 0             960015.0    petrol       2000.0     black    mechanics
# 1             172000.0    diesel       1400.0    silver    mechanics
# 2             223000.0    petrol       2500.0    purple         auto
# 3             140000.0    petrol       1200.0      blue    mechanics
# 4             413000.0    diesel       2200.0  burgundy    mechanics
#
#           drive_unit segment
# 0  front-wheel drive       D
# 1  front-wheel drive       M
# 2  front-wheel drive       D
# 3  front-wheel drive       A
# ...

# %% [markdown]
# make- Company of Car
# model - Model belong to company
# priceUsd - price of model in US Dollar
# year -
# Condition- damage or not
# mileage - ?
# fuel_type - petrol or diesel
# volume - capacity of tank
# color - color of car
# transmission - operating mechanism
# drive_unit - ?
# segment - ?

# %%
for col in df.columns:
    print(col, str(round(100 * df[col].isnull().sum()/ len(df), 2))+ '%')
# Out:
# Unnamed: 0 0.0%
# make 0.0%
# model 0.0%
# priceUSD 0.0%
# year 0.0%
# condition 0.0%
# mileage(kilometers) 0.0%
# fuel_type 0.0%
# volume(cm3) 0.08%
# color 0.0%
# transmission 0.0%
# drive_unit 3.36%
# segment 9.39%

# %%
df['drive_unit'].value_counts()
# Out:
# front-wheel drive             27074
# rear drive                     4809
# all-wheel drive                4176
# part-time four-wheel drive     2596
# Name: drive_unit, dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0       priceUSD          year  mileage(kilometers)  \
# count  40000.00000   40000.000000  40000.000000         4.000000e+04
# mean   19999.50000    7430.383775   2003.485625         2.434332e+05
# std    11547.14972    8338.242134      8.114896         3.167033e+05
# min        0.00000      95.000000   1938.000000         0.000000e+00
# 25%     9999.75000    2350.000000   1998.000000         1.370000e+05
# 50%    19999.50000    5350.000000   2004.000000         2.280000e+05
# 75%    29999.25000    9850.000000   2010.000000         3.087610e+05
# max    39999.00000  195000.000000   2019.000000         9.999999e+06
#
#         volume(cm3)
# count  39970.000000
# mean    2103.201676
# std      938.724653
# min      500.000000
# 25%     1600.000000
# 50%     1995.000000
# 75%     2300.000000
# max    20000.000000

# %%
df.isnull().any()
# Out:
# Unnamed: 0             False
# make                   False
# model                  False
# priceUSD               False
# year                   False
# condition              False
# mileage(kilometers)    False
# fuel_type              False
# volume(cm3)             True
# color                  False
# transmission           False
# drive_unit              True
# segment                 True
# dtype: bool

# %% [markdown]
# So, We have Volume, Segment, drive_unit columns which has missing values

# %%
df['segment'].value_counts()
# Out:
# D    8985
# C    7509
# J    6161
# M    4532
# E    4391
# B    3128
# F     658
# S     549
# A     332
# Name: segment, dtype: int64

# %% [markdown]
# so we have 9 types of segment of Cars listed as:
#     A- small sedan
#     B - large than A
#     C- larger than B

# %%
def plotbar(col):
    fig = plt.figure(figsize=(12,6))
    plt.style.use('fast')

    sns.barplot(x=df['make'].value_counts().values[:20],
           y=df['make'].value_counts().index[:20])

    
    plt.xlabel('Car')
    plt.ylabel('')
    plt.title('Top 20 Cars present in data ')

    plt.show()

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
fig = plt.figure(figsize=(12,6))
plt.style.use('fast')

sns.barplot(x=df['make'].value_counts().values[:20],
           y=df['make'].value_counts().index[:20])

plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=15)
plt.xlabel('Car')
plt.ylabel('')
plt.title('Top 20 Cars present in data ')

plt.show()

# %%
fig = plt.figure(figsize=(12,6))
plt.style.use('fast')

sns.barplot(x=df['segment'].value_counts().values,
           y=df['segment'].value_counts().index)

plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=15)
plt.xlabel('Car')
plt.ylabel('')
plt.title('Which kind of segment is most popular ')

plt.show()

# %% [markdown]
# A Segment Cars (under 800 CC) - Entry Level Cars with Length under 3.6 Meter
#
# B Segment Cars (1.2 Litre in Petrol n 1.3 Litre in Diesel) - Compact Cars with Length under 4 Meter
#
# C Segment Cars (1.2 Lit - 1.6 Litre) - Mid Size Cars with Length > 4 Meter and Price from Rs. 5 Lac - 10 Lac
#
# D Segment Cars (1.6 Litre - 2 Litre) - Mid Executive Cars with Length > 4 Meter and Price from Rs. 10 Lac - 20 Lac
#
# E-segment executive cars
#
# S-segment sports coupés
#
# J-segment sport utility cars

# %%
plt.rcParams['figure.figsize']= (15,7)

plt.subplot(1,2,1)
plt.style.use('fast')

sns.barplot(x=df['transmission'].value_counts().index,
           y=df['transmission'].value_counts(normalize=True).values)

plt.tick_params(axis='x', labelsize=10)
plt.tick_params(axis='y', labelsize=15)
plt.xlabel('Car')
plt.ylabel('')
plt.title('Popular Transmission Mode')


plt.subplot(1,2,2)
labels = df['drive_unit'].value_counts().index
size = df['drive_unit'].value_counts()
colors = ['lightgreen', 'orange', 'aqua', 'purple']
explode = [0.2, 0.3, 0.4,0.]


plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Drive_Unit', fontsize = 20)
plt.axis('off')
plt.legend()

plt.show()

# %%
plt.rcParams['figure.figsize']= (15,7)

plt.subplot(1,2,1)
sns.set(style='whitegrid')

sns.distplot(df['priceUSD'], color='red')
plt.title('Price of Model in USD', fontsize=20)
plt.xlabel('range of USD')
plt.ylabel('count')


plt.subplot(1,2,2)
labels = df['condition'].value_counts().index
size = df['condition'].value_counts()
colors = ['lightgreen', 'orange', 'aqua']
explode = [0.2, 0.3, 1]


plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Condition of Car', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
print(df.priceUSD.describe(percentiles = [0.25,0.50,0.75,0.85,0.90,1]))
# Out:
# count     40000.000000
# mean       7430.383775
# std        8338.242134
# min          95.000000
# 25%        2350.000000
# 50%        5350.000000
# 75%        9850.000000
# 85%       12900.000000
# 90%       15211.000000
# 100%     195000.000000
# max      195000.000000
# Name: priceUSD, dtype: float64

# %% [markdown]
# Graph is right skewed so Most of the price is below 10000

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
df.head()
# Out:
#    Unnamed: 0        make    model  priceUSD  year     condition  \
# 0           0       honda   accord       565  1993  with mileage
# 1           1        ford   fusion      5550  2008  with mileage
# 2           2      nissan    teana      8300  2008  with mileage
# 3           3  volkswagen      fox      3300  2005  with mileage
# 4           4      nissan  primera      2450  2002   with damage
#
#    mileage(kilometers) fuel_type  volume(cm3)     color transmission  \
# 0             960015.0    petrol          2.0     black    mechanics
# 1             172000.0    diesel          1.4    silver    mechanics
# 2             223000.0    petrol          2.5    purple         auto
# 3             140000.0    petrol          1.2      blue    mechanics
# 4             413000.0    diesel          2.2  burgundy    mechanics
#
#           drive_unit segment
# 0  front-wheel drive       D
# 1  front-wheel drive       M
# 2  front-wheel drive       D
# 3  front-wheel drive       A
# ...

# %%
df.groupby(['segment', 'transmission'])['mileage(kilometers)'].agg(['mean', 'median', 'std', 'min','max'])
# Out:
#                                mean    median            std   min        max
# segment transmission
# A       auto          132606.440476  120210.0   70492.316008  10.0   378000.0
#         mechanics     168706.008065  170000.0   91551.769342   0.0   389000.0
# B       auto          120014.445031  105380.0  100043.558494   0.0  1580000.0
#         mechanics     178805.816000  158000.0  318542.923657   0.0  9999999.0
# C       auto          167617.647526  152000.0  273784.808555   0.0  9999999.0
#         mechanics     257471.905581  250000.0  315180.099331   0.0  9999999.0
# D       auto          207878.748260  200000.0  149023.983857   0.0  3333333.0
#         mechanics     311630.838855  296276.5  430535.036873   0.0  9999999.0
# E       auto          268113.266621  260000.0  208405.453325   0.0  4000000.0
#         mechanics     338849.172517  320000.0  399094.138074   0.0  9999999.0
# F       auto          270563.931854  270000.0  170589.868633   0.0  3376558.0
# ...

# %% [markdown]
# Insights
#
# In each segment mechanics transmission gives better mileage than auto transmission
# small segments cars gives less mileage compared to large segment one
# In case of fully executive and executive cars, executive cars have better avg mileage

# %%
#lets convert cm3 to l 
df['mileage(kilometers)'] = df['mileage(kilometers)'].apply(lambda x: x/1000)

# %%
df.groupby(['segment'])['mileage(kilometers)', 'volume(cm3)','priceUSD'].agg(['mean', 'median', 'std', 'min','max'])
# Out:
#         mileage(kilometers)                                     volume(cm3)  \
#                        mean   median         std  min       max        mean
# segment
# A                159.572383  155.000   88.021177  0.0   389.000    1.326584
# B                169.821713  150.000  296.535161  0.0  9999.999    1.481072
# C                238.194344  219.999  308.962643  0.0  9999.999    1.687727
# D                283.582555  270.000  378.642495  0.0  9999.999    1.989482
# E                308.370390  300.000  332.516794  0.0  9999.999    2.399049
# F                272.758064  275.000  169.484311  0.0  3376.558    3.703321
# J                182.345636  170.000  190.711623  0.0  9999.999    2.611288
# M                274.026833  270.000  280.893170  0.0  9999.999    1.968469
# S                220.363567  205.000  133.500576  0.0  1111.111    3.844852
#
#                                            priceUSD                         \
# ...

# %%
df.groupby(['segment', 'transmission'])['volume(cm3)'].agg(['mean', 'median', 'std', 'min','max'])
# Out:
#                           mean  median       std    min   max
# segment transmission
# A       auto          1.525381     1.6  0.284205  0.800   2.0
#         mechanics     1.259250     1.3  0.341368  0.796   2.0
# B       auto          1.527908     1.6  0.149452  1.000   1.8
#         mechanics     1.472624     1.4  0.931332  0.500  20.0
# C       auto          1.694233     1.6  0.629432  0.600  20.0
#         mechanics     1.685949     1.6  0.748447  0.500  20.0
# D       auto          2.119077     2.0  0.397352  1.400   4.2
#         mechanics     1.941480     1.9  0.978425  1.111  20.0
# E       auto          2.603349     2.5  0.544085  1.600   6.2
#         mechanics     2.244374     2.2  0.587746  0.500  20.0
# F       auto          3.741815     3.6  0.841670  2.000   6.6
#         mechanics     2.803704     2.8  0.426508  1.900   3.5
# J       auto          2.834584     2.7  0.998544  1.197  20.0
#         mechanics     2.044391     2.0  0.602205  0.500  16.0
# ...

# %% [markdown]
# Insight
#
# Looks like Auto transmission car need large tanks of fuel.
# S segment and F segment car need large tanks

# %%
df['volume(cm3)'] = df['volume(cm3)'].apply(lambda x: x/1000)

# %%
df.groupby(['segment', 'transmission', 'fuel_type'])['fuel_type'].count().plot();

# %% [markdown]
# Insight
#
# People prefer to use petrol as fuel over diesel
# But for M segment mechanics transmission people prefer diesel

# %%
df.groupby(['segment', 'transmission','year'])['priceUSD'].agg(['min', 'max'])
# Out:
#                              min    max
# segment transmission year
# A       auto         1998   2650   2650
#                      1999   3500   3800
#                      2000   2700   3600
#                      2001   3850   4300
#                      2002   3500   4350
# ...                          ...    ...
# S       mechanics    2004  13200  13200
#                      2005   9000  10550
#                      2006  13500  50000
#                      2009   8000   8000
#                      2012  18900  18900
#
# [605 rows x 2 columns]

# %%
df[df['make']=='honda'].groupby('model')['priceUSD'].agg(['mean', 'median', 'std'])
# Out:
#                    mean   median          std
# model
# accord      6450.914141   4099.5  5886.076828
# civic       5596.905213   5890.0  4283.325912
# concerto     814.000000    800.0   262.640439
# cr-v       12159.838384  11000.0  6600.453970
# cr-z        9400.000000   9500.0  1153.256259
# crosstour  17825.000000  17400.0  3167.293798
# element     8157.777778   7700.0  1301.218446
# fit         8750.800000   7975.0  2745.903295
# fr-v        7199.857143   7100.0  1040.897118
# hr-v        5843.687500   4250.0  4922.824822
# insight     7726.666667   7450.0  1537.491773
# jazz        5052.500000   4430.0  2125.015686
# legend      6421.875000   6338.0  4031.028739
# odyssey    12877.285714  13000.0  3821.255322
# pilot      14156.000000  13600.0  6341.122185
# ridgeline  13958.333333  14050.0  3980.253342
# shuttle     2566.000000   2180.0  1057.896025
# stream      4169.800000   4250.0  1120.439735

# %%
df.groupby('segment')['priceUSD'].agg(['mean', 'median', 'std'])
# Out:
#                  mean   median           std
# segment
# A         4560.743976   3300.0   4504.230142
# B         4325.038363   3500.0   3615.639021
# C         4872.817020   3750.0   4130.657874
# D         5322.893823   3800.0   4884.388105
# E         6238.832840   4150.0   6870.122464
# F        10901.606383   8387.5  10303.335800
# J        14516.228697  12000.0  11247.409250
# M         6916.101500   5500.0   5077.310272
# S        17349.550091  12200.0  17226.399763

# %%
df.groupby(['segment','year'])['priceUSD'].agg(['min', 'max'])
# Out:
#                 min     max
# segment year
# A       1962   2000    2000
#         1967   1190    4200
#         1968    350    1600
#         1996    500    1000
#         1997    350    1950
# ...             ...     ...
# S       2015  17300   82000
#         2016  24999   95000
#         2017  25450  119000
#         2018  23700   78990
#         2019  77773   78649
#
# [377 rows x 2 columns]

# %%
df.groupby(['segment','drive_unit'])['priceUSD'].agg(['mean', 'median', 'std'])
# Out:
#                                             mean   median           std
# segment drive_unit
# A       front-wheel drive            4581.032680   3350.0   4544.151236
#         rear drive                   5375.875000   2783.5   6041.024427
# B       front-wheel drive            4775.903832   4200.0   3619.881098
#         rear drive                    915.216049    600.0   1008.851535
# C       all-wheel drive              8859.814815   6800.0   6454.324515
#         front-wheel drive            4833.620105   3700.0   4046.962471
#         part-time four-wheel drive  19342.857143  14000.0  12624.296303
#         rear drive                   8801.461538   8300.0   5614.633890
# D       all-wheel drive             10098.270548   7750.0   8101.299094
#         front-wheel drive            5100.526523   3636.5   4495.943927
#         part-time four-wheel drive   8397.564516   5175.0   8990.371251
#         rear drive                   5781.981095   4300.0   5389.563257
# ...

# %%
Four wheel drive and all wheel drive has high price

# %%
#lets check how price is 
df[df['make']=='honda']
# Out:
#        Unnamed: 0   make   model  priceUSD  year     condition  \
# 0               0  honda  accord       565  1993  with mileage
# 73             73  honda     fit     11199  2015  with mileage
# 89             89  honda   civic      1200  1992  with mileage
# 233           233  honda    cr-v      4499  2000  with mileage
# 336           336  honda   civic      6700  2009  with mileage
# ...           ...    ...     ...       ...   ...           ...
# 39667       39667  honda  accord      1500  1995  with mileage
# 39771       39771  honda  accord      1800  1997  with mileage
# 39848       39848  honda   civic      1650  1998  with mileage
# 39938       39938  honda  accord      3500  2000  with mileage
# 39973       39973  honda    cr-v     19600  2015  with mileage
#
#        mileage(kilometers) fuel_type  volume(cm3)     color transmission  \
# 0                 960015.0    petrol          2.0     black    mechanics
# ...

# %%
sns.lineplot()

# %%
d =df.groupby(["segment", "year"]).agg("mean").reset_index()

# %%
fig = plt.figure(figsize=(20,8))
plt.style.use('fast')
sns.lineplot(x='year', y='priceUSD', hue='segment', data=d);
plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
plt.xlabel('year', fontsize=18)
plt.ylabel('priceUSD', fontsize=18)
# Out:
# Text(0, 0.5, 'priceUSD')

# %% [markdown]
# after 2007 almost every segment price has increased
# Executive, Fully executive , sports,J-segment has increased exponentially

# %%
b=df.groupby(["segment","make","year"]).agg("mean").reset_index()

# %%
fig = plt.figure(figsize=(20,8))
plt.style.use('fast')
sns.lineplot(x='year', y='priceUSD', hue='make', data=b);
plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
plt.xlabel('year', fontsize=18)
plt.ylabel('priceUSD', fontsize=18)
# Out:
# Text(0, 0.5, 'priceUSD')

# %% [markdown]
# Does Condition of Car depends on fuel_type?
#
# H0- It does not
# H1 - It does

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
table = pd.crosstab(df.condition, df.fuel_type)
stat, p, dof, expected = chi2_contingency(table)

# %%
table
# Out:
# fuel_type     diesel  electrocar  petrol
# condition
# for parts         73           0     249
# with damage       81           0     260
# with mileage   13947          30   25360

# %%
prob = 0.95
alpha = 1.0 - prob
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')

# %%
So Null hypothesis gets rejected Condition of car does depend on fuel_type

# %%
df.head()
# Out:
#    Unnamed: 0        make    model  priceUSD  year     condition  \
# 0           0       honda   accord       565  1993  with mileage
# 1           1        ford   fusion      5550  2008  with mileage
# 2           2      nissan    teana      8300  2008  with mileage
# 3           3  volkswagen      fox      3300  2005  with mileage
# 4           4      nissan  primera      2450  2002   with damage
#
#    mileage(kilometers) fuel_type  volume(cm3)     color transmission  \
# 0             960015.0    petrol       2000.0     black    mechanics
# 1             172000.0    diesel       1400.0    silver    mechanics
# 2             223000.0    petrol       2500.0    purple         auto
# 3             140000.0    petrol       1200.0      blue    mechanics
# 4             413000.0    diesel       2200.0  burgundy    mechanics
#
#           drive_unit segment
# 0  front-wheel drive       D
# 1  front-wheel drive       M
# 2  front-wheel drive       D
# 3  front-wheel drive       A
# ...

# %% [markdown]
# Does Condition of Car depends on transmission?
#
# H0- It does not
# H1 - It does

# %%
table = pd.crosstab(df.condition, df.transmission)
stat, p, dof, expected = chi2_contingency(table)

# %%
prob = 0.95
alpha = 1.0 - prob
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# Dependent (reject H0)

# %%
table
# Out:
# transmission   auto  mechanics
# condition
# for parts        19        303
# with damage      87        254
# with mileage  14264      25073

# %% [markdown]
# Does Condition of Car depends on color?
#
# H0- It does not
# H1 - It does

# %%
table = pd.crosstab(df.condition, df.color)
stat, p, dof, expected = chi2_contingency(table)

# %%
prob = 0.95
alpha = 1.0 - prob
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# Dependent (reject H0)

# %%
table
# Out:
# segment         A     B     C     D     E    F     J     M    S
# condition
# for parts       4    34   110    91    31    0     4     8    2
# with damage     0    31    84    81    36    8    26    18    5
# with mileage  328  3063  7315  8813  4324  650  6131  4506  542

# %% [markdown]
# Does Condition of Car depends on Segment?
#
# H0- It does not
# H1 - It does

# %%
table = pd.crosstab( df.condition, df.segment)
stat, p, dof, expected = chi2_contingency(table)

# %%
prob = 0.95
alpha = 1.0 - prob
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# Dependent (reject H0)

# %%
table
# Out:
# segment         A     B     C     D     E    F     J     M    S
# condition
# for parts       4    34   110    91    31    0     4     8    2
# with damage     0    31    84    81    36    8    26    18    5
# with mileage  328  3063  7315  8813  4324  650  6131  4506  542

# %%
Does Condition of Car depends on transmission?

H0- It does not
H1 - It does

# %%
table = pd.crosstab( df.model, df.make)
stat, p, dof, expected = chi2_contingency(table)

prob = 0.95
alpha = 1.0 - prob
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# Dependent (reject H0)

# %%
table
# Out:
# fuel_type                   diesel  electrocar  petrol
# drive_unit
# all-wheel drive               1520           5    2651
# front-wheel drive             9339          17   17718
# part-time four-wheel drive    1023           2    1571
# rear drive                    1780           5    3024

# %%
table = pd.crosstab( df.drive_unit, df.make)
stat, p, dof, expected = chi2_contingency(table)

prob = 0.95
alpha = 1.0 - prob
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# Dependent (reject H0)

# %%
import statsmodels.api as sm
import numpy as np
Y = df['priceUSD']
X = df['mileage(kilometers)']
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               priceUSD   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     1216.
# Date:                Thu, 19 Nov 2020   Prob (F-statistic):          1.48e-262
# Time:                        12:42:31   Log-Likelihood:            -4.1730e+05
# No. Observations:               40000   AIC:                         8.346e+05
# Df Residuals:                   39998   BIC:                         8.346e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
df['segment'].value_counts()
# Out:
# D    8985
# C    7509
# J    6161
# M    4532
# E    4391
# B    3128
# F     658
# S     549
# A     332
# Name: segment, dtype: int64

# %%
df.shape
# Out:
# (40000, 13)

# %%
df['segment']
# Out:
# 0          D
# 1          M
# 2          D
# 3          A
# 4          D
#         ...
# 39995      J
# 39996      E
# 39997      D
# 39998    NaN
# 39999      D
# Name: segment, Length: 40000, dtype: object

# %%
df.groupby(['segment'])['mileage(kilometers)', 'volume(cm3)','priceUSD'].agg(['mean', 'median', 'std', 'min','max'])
# Out:
#         mileage(kilometers)                                     volume(cm3)  \
#                        mean   median         std  min       max        mean
# segment
# A                159.572383  155.000   88.021177  0.0   389.000    1.326584
# B                169.821713  150.000  296.535161  0.0  9999.999    1.481072
# C                238.194344  219.999  308.962643  0.0  9999.999    1.687727
# D                283.582555  270.000  378.642495  0.0  9999.999    1.989482
# E                308.370390  300.000  332.516794  0.0  9999.999    2.399049
# F                272.758064  275.000  169.484311  0.0  3376.558    3.703321
# J                182.345636  170.000  190.711623  0.0  9999.999    2.611288
# M                274.026833  270.000  280.893170  0.0  9999.999    1.968469
# S                220.363567  205.000  133.500576  0.0  1111.111    3.844852
#
#                                            priceUSD                         \
# ...

# %%
function to get missing value

def segment(i,vol, price):
    
   
        
            
        
            
    if vol[i] < 1.3 and price[i] < 34000:
        return 'A'
    elif vol[i] >= 1.3 and vol[i] <= 1.4 and price[i] < 25000:
        return 'B'
        
    elif vol[i] > 1.4 and vol[i] <= 1.6 and price[i] < 41000:
        return 'C'
    elif vol[i] > 1.6 and vol[i] < 2 and price[i]  < 55000:
        return 'D'
    
    elif vol[i] >= 2 and vol[i] < 2.5 and price[i]  < 82000:
        return 'E'
    elif vol[i] > 3 and vol[i] <= 3.7 and price[i]  < 110000:
        return 'F'
    elif vol[i] > 2.3 and vol[i] < 3 and price[i]  < 170000:
        return 'J'
    elif vol[i] > 1.8 and vol[i] < 2.1 and price[i]  < 51000:
        return 'M'
    elif vol[i] > 3.3 and price[i]  < 120000:
        return 'S'

# %%
df['volume(cm3)'].describe()
# Out:
# count    39970.000000
# mean         2.103202
# std          0.938725
# min          0.500000
# 25%          1.600000
# 50%          1.995000
# 75%          2.300000
# max         20.000000
# Name: volume(cm3), dtype: float64

# %%
data = df.copy()

# %%
data['segment']=data['segment'].fillna(0)

# %%
d=[]
for i in range(len(data['priceUSD'])):
 
               
    if data['segment'].values[i] !=0:
        d.append(data['segment'][i])
               
    else:
               
        d.append(segment(i,data['volume(cm3)'], data['priceUSD']))

# %%
data['segment']=d

# %%
# Out:
# 0        D
# 1        M
# 2        D
# 3        A
# 4        D
#         ..
# 39995    J
# 39996    E
# 39997    D
# 39998    B
# 39999    D
# Name: segment, Length: 40000, dtype: object

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (38498, 13)

# %%
seg_map ={'A':1,
          'B':2,
          'C':3,
          'D':4,
          'E':5,
          'F':6,
          'J':7,
          'M':8,
          'S':9
          
    
}

# %%
data.loc[:, 'segment'] = data.segment.map(seg_map)

# %%
data.drop(['Unnamed: 0', 'make','model'], inplace=True,axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38498 entries, 0 to 39999
# Data columns (total 10 columns):
# priceUSD               38498 non-null int64
# year                   38498 non-null int64
# condition              38498 non-null object
# mileage(kilometers)    38498 non-null float64
# fuel_type              38498 non-null object
# volume(cm3)            38498 non-null float64
# color                  38498 non-null object
# transmission           38498 non-null object
# drive_unit             38498 non-null object
# segment                38498 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 3.2+ MB

# %%
data
# Out:
#        priceUSD  year     condition  mileage(kilometers) fuel_type  \
# 0           565  1993  with mileage              960.015    petrol
# 1          5550  2008  with mileage              172.000    diesel
# 2          8300  2008  with mileage              223.000    petrol
# 3          3300  2005  with mileage              140.000    petrol
# 4          2450  2002   with damage              413.000    diesel
# ...         ...   ...           ...                  ...       ...
# 39995     12500  2008  with mileage              214.000    petrol
# 39996      4754  2001  with mileage              295.000    petrol
# 39997      4000  1999  with mileage                0.000    diesel
# 39998      1200  1996  with mileage              250.000    petrol
# 39999       744  1986  with mileage              272.344    diesel
#
#        volume(cm3)     color transmission         drive_unit  segment
# 0            2.000     black    mechanics  front-wheel drive        4
# ...

# %%
cond_map ={'with mileage':0,
           'with damage':1,
           'for parts':2
    
}

# %%
data.loc[:, 'condition'] = data.condition.map(cond_map)

# %%
data.color.value_counts().index.values
# Out:
# array(['black', 'silver', 'blue', 'gray', 'white', 'green', 'other',
#        'red', 'burgundy', 'brown', 'purple', 'yellow', 'orange'],
#       dtype=object)

# %%
color_map={}
for i,val in enumerate(data.color.value_counts().index.values):
    color_map[val] =i

# %%
data.loc[:, 'color'] = data.color.map(color_map)

# %%
trans_map={}
for i,val in enumerate(data.transmission.value_counts().index.values):
    trans_map[val] =i

# %%
data.loc[:, 'transmission'] = data.transmission.map(trans_map)

# %%
drive_unit_map={}
for i,val in enumerate(data.drive_unit.value_counts().index.values):
    drive_unit_map[val] =i

# %%
data.loc[:, 'drive_unit'] = data.drive_unit.map(drive_unit_map)

# %%
fuel_map={}
for i,val in enumerate(data.fuel_type.value_counts().index.values):
    fuel_map[val] =i

# %%
data.loc[:, 'fuel_type'] = data.fuel_type.map(fuel_map)

# %%
data.to_csv('converted.csv')

# %%
from sklearn import model_selection

# %%
data['kfold'] = -1
data = data.sample(frac=1).reset_index(drop=True)
kf = model_selection.KFold(n_splits=5)

for fold, (train_idx, val_idx) in enumerate(kf.split(X=data[['priceUSD']])):
    data.loc[val_idx, 'kfold'] = fold

data.to_csv('train_folds1.csv')

# %%
# we create new column and fill it -1
data['kfold'] = -1
# randomize the data
data = data.sample(frac=1).reset_index(drop=True)
# calculating number of bins
num_bins = np.floor(1 + np.log2(len(data)))
# column on which we want to validate
data.loc[:, 'bins'] = pd.cut(x=data['priceUSD'], bins=num_bins, labels=False)
# initiate kFold
kf = model_selection.StratifiedKFold(n_splits=5)

for fold, (train_idx, val_idx) in enumerate(kf.split(X=data['priceUSD'],y=data.bins.values)):
    data.loc[val_idx, 'kfold'] = fold
data.drop('bins',axis=1,inplace=True)
data.to_csv('reg_stratified.csv')
# Out:
# C:\Users\thaku\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)

# %%
from sklearn.ensemble import RandomForestRegressor
